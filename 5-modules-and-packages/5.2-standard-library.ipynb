# %%
import array

arr = array.array("i", [1,2,3,4,5])

print(arr.pop())
print(len(arr))
# Out:
# 5
# 4

# %%
import math

math.ceil(6.4)
math.e
math.dist((1,2), (0,0))
# Out:
# 2.23606797749979

# %%
import random

random.randint(0, 10)
math.floor(random.random() * 10)
random.choice(["apple", "mango", "banana"])
# Out:
# 'apple'

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/vineetjain
# ['Music', '.DS_Store', '.CFUserTextEncoding', '.zshrc', 'Pictures', 'Workspace', '.zprofile', '.zsh_history', '.ipython', 'Desktop', 'Library', '.lesshst', '.zcompdump-Vineet’s MacBook Pro-5.9', '.node_repl_history', '.cups', 'Public', '.ssh', 'Movies', '.Trash', '.npm', 'Documents', '.vscode', '.bash_profile', '.oh-my-zsh', 'Downloads', '.python_history', '.gitconfig', '.viminfo', '.zsh_sessions', '.conda']

# %%
import shutil
import os
print(os.getcwd())
shutil.copyfile("src.txt", "dest.txt")
# Out:
# /Users/vineetjain/Workspace/learning/python/5-modules-and-packages
# 'dest.txt'

# %%
# serialising and deserialising the data

import json

data = {"name": "Vineet", "age": 21}

data_str = json.dumps(data)
parsed_data = json.loads(data_str)

print(type(data_str))
print(type(parsed_data))
# Out:
# <class 'str'>
# <class 'dict'>

# %%
# csv

import csv

with open('example.csv', mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["roll_no", "name"])
    writer.writerow([45509, "Vineet Jain"])

with open ('example.csv', mode="r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['roll_no', 'name']
# ['45509', 'Vineet Jain']

# %%
from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(1)
print(yesterday)
# Out:
# 2025-06-13 01:02:47.350572
# 2025-06-12 01:02:47.350572

# %%
import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1749756901.541719
# 1749756903.546345

# %%
## regexp
import re

pattern = r'\d+'
text = "hello 42859 also called Vineet code 05"

match = re.search(pattern, text)

print(match.group())
# Out:
# 42859
