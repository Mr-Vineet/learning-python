# %%
from math import *

print(pi)
sqrt(9)
abs(-194)
# Out:
# 3.141592653589793
# 194

# %%
import numpy as np
from package import stringy

print(stringy.split("Adil Ali"))

str = np.array2string(np.array([2, 3, 4, 5]))
# Out:
# ['Adil', 'Ali']

# %%
from package.sub_package.repeat import repeat

print(repeat("Saransh "))
# Out:
# Saransh Saransh
