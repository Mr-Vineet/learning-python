# %% [markdown]
# ### Effective docstring for a function

# %%
def function_name(param1: int, param2: str = "default") -> bool:
    # Google docstring style template for a function
    
    """
    Brief summary of what the function does.

    Args:
        param1 (int): Description of the first parameter.
        param2 (str, optional): Description of the second parameter.

    Returns:
        bool: Description of the return value.

    Raises:
        ValueError: If `param1` is negative.
    """

# %%
def function_name(param1, param2="default"):
    # numPy docstring style template for a function
    
    """
    Brief summary of the function.

    Parameters
    ----------
    param1 : int
        Description of the first parameter.
    param2 : str, optional
        Description of the second parameter.

    Returns
    -------
    bool
        Description of the return value.
    """
